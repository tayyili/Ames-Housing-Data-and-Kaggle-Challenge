# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Ames Housing Data and Kaggle Challenge
# #                  Appendix 2 - Data Dictionary

# %% [markdown]
# ### Contents:
# - [Data Dictionary](#Data-Dictionary)

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# |Feature  |Type  |Dataset  |Description  |    Item in Feature and Their Meaning   |
# |:---:|:---:|:---:|:---:|:---|
# |**id**|*integer*|all datasets |Unique integer for each entry for identification|Unique integer for each entry|
# |||||
# |**ms_subclass**|*integer*|all datasets|Identifies the type of dwelling involved in the sale|20: 1-Story 1946 & Newer All Styles
# ||| (In dummified dataset, this column is being dummified into **ms_subclass_(value)**)||30: 1-Story 1945 & Older
# |||||40: 1-Story W/Finished Attic All Ages
# |||||45: 1-1/2 Story - Unfinished All Ages
# |||||50: 1-1/2 Story Finished All Ages
# |||||60: 2-Story 1946 & Newer
# |||||70: 2-Story 1945 & Older
# |||||75: 2-1/2 Story All Ages
# |||||80: Split Or Multi-Level
# |||||85: Split Foyer
# |||||90: Duplex - All Styles And Ages
# |||||120: 1-Story PUD (Planned Unit Development) - 1946 & Newer
# |||||150: 1-1/2 Story PUD - All Ages
# |||||160: 2-Story PUD - 1946 & Newer
# |||||180: PUD - Multilevel - Including Split Lev/Foyer
# |||||190: 2 Family Conversion - All Styles And Ages
# |||||
# |**ms_zoning**|*string*|all datasets|Identifies the the general zoning classification of the sale|A: Agriculture
# ||| (In dummified dataset, this column is being dummified into **ms_zoning_(string)**)||C: Commercial
# |||||FV: Floating Village Residential
# |||||I: Industrial
# |||||RH: Residential High Density
# |||||RL: Residential Low Density
# |||||RP: Residential Low Density Park
# |||||RM: Residential Medium Density
# |||||
# |**lot_frontage**|*float*|all datasets|Linear feer of street connected to property|Unique float value
# |||||
# |**lot_area**|*integer*|all datasets|Lot size in square feet|Unique integer value
# |||||
# |**street**|*string*|all datasets|Type of road access to property|Grvl: Gravel
# ||| (In dummified dataset, this column is being dummified into **street_(string)**)||Pave: Paved
# |||||
# |**alley**|*string*|all datasets|Type of alley access to property|Grvl: Gravel
# ||| (In dummified dataset, this column is being dummified into **alley_(string)**)||Pave: Paved
# |||||No: No alley access
# |||||
# |**lot_shape**|*integer*|all datasets|General shape of property|1: Irregular
# |||||2: Moderately Irregular
# |||||3: Slightly irregular
# |||||4: Regular
# |||||
# |**land_contour**|*string*|all datasets|Flatness of the property|Lvl: Near Flat/Level
# |||(In dummified dataset, this column is being dummified into **land_contour_(string)**)||Bnk: Banked - Quick and significant rise from street grade to building
# |||||HLS: Hillside - Significant slope from side to side
# |||||Low: Depression
# |||||
# |**utilities**|*integer*|all datasets|Type of utilities available|1: Electricity only
# |||||2: Electricity and Gas Only
# |||||3: Electricity, Gas, and Water (Septic Tank)
# |||||4: All public Utilities (E,G,W,& S)
# |||||
# |**lot_config**|*string*|all datasets|Lot configuration|Inside: Inside lot
# |||(In dummified dataset, this column is being dummified into **lot_config_(string)**)||Corner: Corner lot
# |||||CulDSac: Cul-de-sac
# |||||FR2: Frontage on 2 sides of property
# |||||FR3: Frontage on 3 sides of property
# |||||
# |**land_slope**|*string*|all datasets|Slope of property|Gtl: Gentle slope
# |||(In dummified dataset, this column is being dummified into **land_slope_(string)**)||Mod: Moderate Slope
# |||||Sev: Severe Slope
# |||||
# |**neighborhood**|*string*|all datasets|Physical locations within Ames city limits|Blmngtn: Bloomington Heights
# |||(In dummified dataset, this column is being dummified into **neighborhood_(string)**)||Blueste: Bluestem
# |||||BrDale: Briardale
# |||||BrkSide: Brookside
# |||||ClearCr: Clear Creek
# |||||CollgCr: College Creek
# |||||Crawfor: Crawford
# |||||Edwards: Edwards
# |||||Gilbert: Gilbert
# |||||Greens: Greens
# |||||GrnHill: Green Hills
# |||||IDOTRR: Iowa DOT and Rail Road
# |||||Landmrk: Landmark
# |||||MeadowV: Meadow Village
# |||||Mitchel: Mitchell
# |||||NAmes: North Ames
# |||||NoRidge Northridge
# |||||NPkVill: Northpark Villa
# |||||NridgHt: Northridge Heights
# |||||NWAmes: Northwest Ames
# |||||OldTown: Old Town
# |||||SWISU: South & West of Iowa State University
# |||||Sawyer: Sawyer
# |||||SawyerW: Sawyer West
# |||||Somerst: Somerset
# |||||StoneBr: Stone Brook
# |||||Timber: Timberland
# |||||Veenker: Veenker
# |||||
# |**condition_1**|*string*|all datasets|Proximity to various conditions|Artery: Adjacent to arterial street
# |||(In dummified dataset, this column is being dummified into **condition_1_(string)**)||Feedr: Adjacent to feeder street
# |||||Norm: Normal
# |||||RRNn: Within 200' of North-South Railroad
# |||||RRAn: Adjacent to North-South Railroad
# |||||PosN: Near positive off-site feature--park, greenbelt, etc.
# |||||PosA: Adjacent to postive off-site feature
# |||||RRNe: Within 200' of East-West Railroad
# |||||RRAe: Adjacent to East-West Railroad
# |||||
# |**condition_2**|*string*|all datasets|Proximity to various conditions (if more than 1 is present)|Artery: Adjacent to arterial street
# |||(In dummified dataset, this column is being dummified into **condition_2_(string)**)||Feedr: Adjacent to feeder street
# |||||Norm: Normal
# |||||RRNn: Within 200' of North-South Railroad
# |||||RRAn: Adjacent to North-South Railroad
# |||||PosN: Near positive off-site feature--park, greenbelt, etc.
# |||||PosA: Adjacent to postive off-site feature
# |||||RRNe: Within 200' of East-West Railroad
# |||||RRAe: Adjacent to East-West Railroad
# |||||
# |**bldg_type**|*string*|all datasets|Type of dwelling|1Fam: Single-family Detached
# |||(In dummified dataset, this column is being dummified into **bldg_type_(string)**)||2FmCon: Two-family Conversion; originally built as one-family dwelling
# |||||Duplex: Duplex
# |||||TwnhsE: Townhouse End Unit
# |||||Twnhs: Townhouse Inside Unit
# |||||
# |**house_style**|*string*|all datasets|Style of dwelling|1Story: One story
# |||(In dummified dataset, this column is being dummified into **house_style_(string)**)||1.5Fin: One and one-half story: 2nd level finished
# |||||1.5Unf: One and one-half story: 2nd level unfinished
# |||||2Story: Two story
# |||||2.5Fin: Two and one-half story: 2nd level finished
# |||||2.5Unf: Two and one-half story: 2nd level unfinished
# |||||SFoyer: Split Foyer
# |||||SLvl: Split Level
# |||||
# |**overall_qual**|*integer*|all datasets|Rates the overall material and finish of the house|1: Very Poor
# |||||2: Poor
# |||||3: Fair
# |||||4: Below Average
# |||||5: Average
# |||||6: Above Average
# |||||7: Good
# |||||8: Very Good
# |||||9: Excellent
# |||||10: Very Excellent
# |||||
# |**overall_cond**|*integer*|all datasets|Rates the overall condition of the house|1: Very Poor
# |||||2: Poor
# |||||3: Fair
# |||||4: Below Average
# |||||5: Average
# |||||6: Above Average
# |||||7: Good
# |||||8: Very Good
# |||||9: Excellent
# |||||10: Very Excellent
# |||||
# |**year_built**|*integer*|all datasets|Original construction date|Unique year values
# |||||
# |**year_remod/add**|*integer*|all datasets|Remodel date (same as construction date if no remodeling or additions)|Unique year values
# |||||
# |**roof_style**|*string*|all datasets|Type of roof|Flat: Flat
# |||(In dummified dataset, this column is being dummified into **roof_style_(string)**)||Gable: Gable
# |||||Gambrel: Gabrel (Barn)
# |||||Hip: Hip
# |||||Mansard: Mansard
# |||||Shed: Shed
# |||||
# |**roof_matl**|*string*|all datasets|Roof material|ClyTile: Clay or Tile
# |||(In dummified dataset, this column is being dummified into **roof_matl_(string)**)||CompShg: Standard (Composite) Shingle
# |||||Membran: Membrane
# |||||Metal: Metal
# |||||Roll: Roll
# |||||Tar&Grv: Gravel & Tar
# |||||WdShake: Wood Shakes
# |||||WdShngl: Wood Shingles
# |||||
# |**exterior_1st**|*string*|all datasets|Exterior covering on house|AsbShng: Asbestos Shingles
# |||(In dummified dataset, this column is being dummified into **exterior_1st_(string)**)||AsphShn: Asphalt Shingles
# |||||BrkComm: Brick Common
# |||||BrkFace: Brick Face
# |||||CBlock: Cinder Block
# |||||CemntBd: Cement Board
# |||||HdBoard: Hard Board
# |||||ImStucc: Imitation Stucco
# |||||MetalSd: Metal Siding
# |||||Other: Other
# |||||Plywood: Plywood
# |||||PreCast: PreCast
# |||||Stone: Stone
# |||||Stucco: Stucco
# |||||VinylSd: Vinyl Siding
# |||||WdSdng: Wood Siding
# |||||WdShing: Wood Shingles
# |||||
# |**exterior_2nd**|*string*|all datasets|Exterior covering on house (if more than 1 material)|AsbShng: Asbestos Shingles
# |||(In dummified dataset, this column is being dummified into **exterior_2nd_(string)**)||AsphShn: Asphalt Shingles
# |||||BrkComm: Brick Common
# |||||BrkFace: Brick Face
# |||||CBlock: Cinder Block
# |||||CmentBd: Cement Board
# |||||HdBoard: Hard Board
# |||||ImStucc: Imitation Stucco
# |||||MetalSd: Metal Siding
# |||||Other: Other
# |||||Plywood: Plywood
# |||||PreCast: PreCast
# |||||Stone: Stone
# |||||Stucco: Stucco
# |||||VinylSd: Vinyl Siding
# |||||WdSdng: Wood Siding
# |||||WdShing: Wood Shingles
# |||||
# |**mas_vnr_type**|*string*|all datasets|Masonry veneer type|BrkCmn: Brick Common
# |||(In dummified dataset, this column is being dummified into **mas_vnr_type_(string)**)||BrkFace: Brick Face
# |||||CBlock: Cinder Block
# |||||Stone: Stone
# |||||No: no masonry
# |||||
# |**mas_vnr_area**|*float*|all datasets|Masonry veneer area in square feet|Unique value representing square feet
# |||||
# |**exter_qual**|*integer*|all datasets|Evaluates the quality of the material on the exterior|1: Poor
# |||||2: Fair
# |||||3: Average/Typical
# |||||4: Good
# |||||5: Excellent
# |||||
# |**exter_cond**|*integer*|all datasets|Evaluates the present condition of the material on the exterior|1: Poor
# |||||2: Fair
# |||||3: Average/Typical
# |||||4: Good
# |||||5: Excellent
# |||||
# |**foundation**|*string*|all datasets|Masonry veneer type|BrkTil: Brick & Tile
# |||(In dummified dataset, this column is being dummified into **foundation_(string)**)||CBlock: Cinder Block
# |||||PConc: Poured Contrete
# |||||Slab: Slab
# |||||Stone: Stone
# |||||Wood: Wood
# |||||
# |**bsmt_qual**|*integer*|all datasets|Evaluates the height of the basement|0: No Basement
# |||||1: Poor (<70 inches)
# |||||2: Fair (70-79 inches)
# |||||3: Average/Typical (80-89 inches)
# |||||4: Good (90-99 inches)
# |||||5: Excellent (100+ inches)
# |||||
# |**bsmt_cond**|*integer*|all datasets|Evaluates the general condition of the basement|0: No Basement
# |||||1: Poor - Severe cracking, settling, or wetness
# |||||2: Fair - dampness or some cracking or settling
# |||||3: Typical - slight dampness allowed
# |||||4: Good
# |||||5: Excellent
# |||||
# |**bsmt_exposure**|*integer*|all datasets|Refers to walkout or garden level walls|0: No Basement/No Exposure
# |||||1: Minimum Exposure
# |||||2: Average Exposure (split levels or foyers typically score average or above)
# |||||3: Good Exposure
# |||||
# |**bsmtfin_type_1**|*integer*|all datasets|Rating of basement finished area|0: No Basement
# |||||1: Unfinished
# |||||2: Low Quality
# |||||3: Average Rec Room
# |||||4: Below Average Living Quarters
# |||||5: Average Living Quarters
# |||||6: Good Living Quarters
# |||||
# |**bsmtfin_sf_1**|*float*|all datasets|Type 1 finished square feet|Unique value representing square feet
# |||||
# |**bsmtfin_type_2**|*integer*|all datasets|Rating of basement finished area (if multiple types)|0: No Basement
# |||||1: Unfinished
# |||||2: Low Quality
# |||||3: Average Rec Room
# |||||4: Below Average Living Quarters
# |||||5: Average Living Quarters
# |||||6: Good Living Quarters
# |||||
# |**bsmtfin_sf_2**|*float*|all datasets|Type 2 finished square feet|Unique value representing square feet
# |||||
# |**bsmt_unf_sf**|*float*|all datasets|Unfinished square feet of basement area|Unique value representing square feet
# |||||
# |**total_bsmt_sf**|*float*|all datasets|Total square feet of basement area|Unique value representing square feet
# |||||
# |**heating**|*string*|all datasets|Type of heating|Floor: Floor Furnace
# |||(In dummified dataset, this column is being dummified into **heating_(string)**)||GasA: Gas forced warm air furnace
# |||||GasW: Gas hot water or steam heat
# |||||Grav: Gravity furnace
# |||||OthW: Hot water or steam heat other than gas
# |||||Wall: Wall furnace
# |||||
# |**heating_qc**|*integer*|all datasets|Heating quality and condition|1: Poor
# |||||2: Fair
# |||||3: Average/Typical
# |||||4: Good
# |||||5: Excellent
# |||||
# |**central_air**|*integer*|all datasets|Central air conditioning|0: No conditioning
# |||||1: Have conditioning
# |||||
# |**electrical**|*string*|all datasets|Electrical system|SBrkr: Standard Circuit Breakers & Romex
# |||(In dummified dataset, this column is being dummified into **electrical_(string)**)||FuseA: Fuse Box over 60 AMP and all Romex wiring (Average)
# |||||FuseF: 60 AMP Fuse Box and mostly Romex wiring (Fair)
# |||||FuseP: 60 AMP Fuse Box and mostly knob & tube wiring (poor)
# |||||Mix: Mixed
# |||||
# |**1st_flr_sf**|*integer*|all datasets|First Floor square feet|Unique value representing square feet
# |||||
# |**2nd_flr_sf**|*integer*|all datasets|Second floor square feet|Unique value representing square feet
# |||||
# |**low_qual_fin_sf**|*integer*|all datasets|Low quality finished square feet (all floors)|Unique value representing square feet
# |||||
# |**bsmt_full_bath**|*float*|all datasets|Basement full bathrooms|Unique float numbers representing number of basement full bathrooms
# |||||
# |**bsmt_half_bath**|*float*|all datasets|Basement half bathrooms|Unique float numbers representing number of basement half bathrooms
# |||||
# |**full_bath**|*integer*|all datasets|Full bathrooms above grade|Unique integer representing number of full bathrooms above grade
# |||||
# |**half_bath**|*integer*|all datasets|Half bathrooms above grade|Unique integer representing number of half bathrooms above grade
# |||||
# |**bedroom_abvgr**|*integer*|all datasets|Bedrooms above grade (does NOT include basement bedrooms)|Unique integer representing number of bedrooms above grade
# |||||
# |**kitchen_abvgr**|*integer*|all datasets|Kitchens above grade|Unique integer representing number of kitchens above grade
# |||||
# |**kitchen_qual**|*integer*|all datasets|Kitchen quality|1: Poor
# |||||2: Fair
# |||||3: Average/Typical
# |||||4: Good
# |||||5: Excellent
# |||||
# |**totrms_abvgrd**|*integer*|all datasets|Total rooms above grade (does not include bathrooms)|Unique integer representing number of total rooms above grade
# |||||
# |**functional**|*integer*|all datasets|Home functionality (Assume typical unless deductions are warranted)|1: Salvage only
# |||||2: Severely Damaged
# |||||3: Major Deductions 2
# |||||4: Major Deductions 1
# |||||5: Moderate Deductions
# |||||6: Minor Deductions 2
# |||||7: Minor Deductions 1
# |||||8: Typical Functionality
# |||||
# |**fireplaces**|*integer*|all datasets|Number of fireplaces|Unique integer representing number of fireplaces
# |||||
# |**fireplace_qu**|*integer*|all datasets|Fireplace quality|0: No Fireplace
# |||||1: Poor - Ben Franklin Stove
# |||||2: Fair - Prefabricated Fireplace in basement
# |||||3: Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
# |||||4: Good - Masonry Fireplace in main level
# |||||5: Excellent - Exceptional Masonry Fireplace
# |||||
# |**garage_type**|*string*|all datasets|Garage location|2Types: More than one type of garage
# |||(In dummified dataset, this column is being dummified into **garage_type_(string)**)||Attchd: Attached to home
# |||||Basment: Basement Garage
# |||||BuiltIn: Built-In (Garage part of house - typically has room above garage)
# |||||CarPort: Car Port
# |||||Detchd: Detached from home
# |||||No: No garage
# |||||
# |**garage_finish**|*integer*|all datasets|Interior finish of the garage|0: No Garage
# |||||1: Unfinished
# |||||2: Rough Finished
# |||||3: Finished
# |||||
# |**garage_cars**|*float*|all datasets|Size of garage in car capacity|Unique float number representing size of garage in car capacity
# |||||
# |**garage_area**|*float*|all datasets|Size of garage in square feet|Unique float number representing size of garage in square feet
# |||||
# |**garage_qual**|*integer*|all datasets|Garage quality|0: No Garage
# |||||1: Poor
# |||||2: Fair
# |||||3: Average/Typical
# |||||4: Good
# |||||5: Excellent
# |||||
# |**garage_cond**|*integer*|all datasets|Garage condition|0: No Garage
# |||||1: Poor
# |||||2: Fair
# |||||3: Average/Typical
# |||||4: Good
# |||||5: Excellent
# |||||
# |**paved_drive**|*integer*|all datasets|Paved driveway|0: Dirt/Gravel
# |||||1: Partial Pavement
# |||||2: Paved
# |||||
# |**wood_deck_sf**|*integer*|all datasets|Wood deck area in square feet|Unique integer representing wood deck area in square feet
# |||||
# |**open_porch_sf**|*integer*|all datasets|Open porch area in square feet|Unique integer representing open porch area in square feet
# |||||
# |**enclosed_porch**|*integer*|all datasets|Enclosed porch area in square feet|Unique integer representing enclosed porch area in square feet
# |||||
# |**3ssn_porch**|*integer*|all datasets|Three season porch area in square feet|Unique integer representing three season porch area in square feet
# |||||
# |**screen_porch**|*integer*|all datasets|Screen porch area in square feet|Unique integer representing screen porch area in square feet
# |||||
# |**pool_area**|*integer*|all datasets|Pool area in square feet|Unique integer representing pool area in square feet
# |||||
# |**pool_qc**|*integer*|all datasets|Pool quality|0: No Pool
# |||||2: Fair
# |||||3: Average/Typical
# |||||4: Good
# |||||5: Excellent
# |||||
# |**fence**|*string*|all datasets|Fence quality|GdPrv: Good Privacy
# |||(In dummified dataset, this column is being dummified into **fench_(string)**)||MnPrv: Minimum Privacy
# |||||GdWo: Good Wood
# |||||MnWw: Minimum Wood/Wire
# |||||No: No Fence
# |||||
# |**misc_feature**|*string*|all datasets|Miscellaneous feature not covered in other categories|Elev: Elevator
# |||(In dummified dataset, this column is being dummified into **misc_feature_(string)**)||Gar2: 2nd Garage (if not described in garage section)
# |||||Othr: Other
# |||||Shed: Shed (over 100 SF)
# |||||TenC: Tennis Court
# |||||No: No Mischellaneous Feature
# |||||
# |**misc_val**|*integer*|all datasets|Value of miscellaneous feature|Unique integer representing value of miscellaneous feature
# |||||
# |**mo_sold**|*integer*|all datasets|Month Sold (MM)|Unique integer representing the month sold
# |||||
# |**yr_sold**|*integer*|all datasets|Year Sold (YYYY)|Unique integer representing the year sold
# |||||
# |**sale_type**|*string*|all datasets|Type of sale|WD: Warranty Deed - Conventional
# |||(In dummified dataset, this column is being dummified into **sale_type_(string)**)||CWD: Warranty Deed - Cash
# |||||VWD: Warranty Deed - VA Loan
# |||||New: Home just constructed and sold
# |||||COD: Court Officer Deed/Estate
# |||||Con: Contract 15% Down payment regular terms
# |||||ConLw: Contract Low Down payment and low interest
# |||||ConLI: Contract Low Interest
# |||||ConLD: Contract Low Down
# |||||Oth: Other
# |||||
# |**saleprice**|*integer*|all datasets|Sale price|Unique integer representing the sale price
# |||||
